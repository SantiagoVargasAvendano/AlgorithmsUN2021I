# %% [markdown]
# # Laboratorio 3
# Link de mi página en linkedin: https://www.linkedin.com/in/santiago-vargas-avendano-018b22209/

# %% [markdown]
# ![Linkedin.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Cursos
# ### Python for Data Science
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Data Analysis with Python
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Data Visualization with Python
# ![image.png](data:image/png;base64,...)
