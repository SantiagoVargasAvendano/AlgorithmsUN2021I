# %% [markdown]
# Linkedin Link: https://www.linkedin.com/in/santiago-vargas-avendano-018b22209/

# %% [markdown]
# Linkedin screenshot:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Certificate: ![image.png](data:image/png;base64,...)
